# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import DBSCAN

# %%
data=pd.DataFrame([[4,5],[7.2,4],[1,2],[7,3],[9,5],[6,4],[8,6],[7,7],[6,9],[6,3]])
data
# Out:
#      0  1
# 0  4.0  5
# 1  7.2  4
# 2  1.0  2
# 3  7.0  3
# 4  9.0  5
# 5  6.0  4
# 6  8.0  6
# 7  7.0  7
# 8  6.0  9
# 9  6.0  3

# %%
plt.scatter(data[0],data[1])

# %%
dbscan=DBSCAN(eps=2,min_samples=3)
dbscan.fit(data)
# Out:
# DBSCAN(eps=2, min_samples=3)

# %%
dbscan.labels_
# Out:
# array([-1,  0, -1,  0,  1,  0,  1,  1, -1,  0], dtype=int64)

# %%
plt.scatter(data[0],data[1],c=dbscan.labels_)
