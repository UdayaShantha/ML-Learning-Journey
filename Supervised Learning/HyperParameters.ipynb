# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("iris_dataset_KNN.csv")
data=data.head(50)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
pred=model.predict(x_test)
pred
# Out:
# array(['versicolor', 'virginica', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'virginica', 'versicolor',
#        'versicolor', 'versicolor'], dtype=object)

# %%
model.score(x_test,y_test)  #get the accuracy of testing values
# Out:
# 0.2

# %%
#for GridSearchCV
from sklearn.model_selection import GridSearchCV #import grid serach cv library
param_grid={'C':[0.1,1,10],'kernel':["rbf","linear","poly"]}  #give the parameter set to get highest accuracy parameter combination

# %%
grid_search=GridSearchCV(estimator=model,param_grid=param_grid)  #using grid search cv give the model and it's parameter list
grid_search.fit(x_train,y_train)     #train data with all the given parameter combinations
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10],
#                          'kernel': ['rbf', 'linear', 'poly']})

# %%
grid_search.best_params_   #give the highest accuracy parameter list from given list and values of parameters
# Out:
# {'C': 10, 'kernel': 'poly'}

# %%
grid_search.score(x_test,y_test)
# Out:
# 0.1

# %%
#for RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV 
param_dist={'C':[0.1,1,5,4,3,2,6,7],'kernel':["rbf","linear","poly"]}

# %%
randomized_search=RandomizedSearchCV(estimator=model,param_distributions=param_dist,n_iter=10) #n_iter means how many combinations wants to consider 
randomized_search.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(estimator=SVC(),
#                    param_distributions={'C': [0.1, 1, 5, 4, 3, 2, 6, 7],
#                                         'kernel': ['rbf', 'linear', 'poly']})

# %%
randomized_search.best_params_
# Out:
# {'kernel': 'poly', 'C': 4}

# %%
grid_search.score(x_test,y_test)
