# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("car_purchase_data_200.csv")
data.head(50)
# Out:
#     Age  Income Marital_Status  Children Car_Purchased
# 0    30  Medium        Married         4            No
# 1    54    High        Married         3           Yes
# 2    49     Low         Single         3            No
# 3    39     Low        Married         2           Yes
# 4    57  Medium         Single         2            No
# 5    36  Medium         Single         3           Yes
# 6    56  Medium        Married         2            No
# 7    29  Medium         Single         0           Yes
# 8    22  Medium         Single         3           Yes
# 9    30  Medium        Married         4            No
# 10   27  Medium         Single         4           Yes
# 11   37    High        Married         1           Yes
# 12   37  Medium        Married         3            No
# 13   18    High         Single         2            No
# 14   27    High         Single         3           Yes
# 15   49     Low        Married         1           Yes
# 16   40  Medium         Single         2           Yes
# 17   42     Low         Single         1            No
# 18   47     Low        Married         2           Yes
# 19   20    High        Married         1           Yes
# 20   45     Low        Married         3           Yes
# 21   52    High         Single         3           Yes
# 22   48     Low         Single         1            No
# 23   33  Medium        Married         1           Yes
# 24   47  Medium         Single         1           Yes
# 25   42  Medium         Single         0           Yes
# 26   23  Medium        Married         2            No
# 27   47     Low        Married         2            No
# 28   24     Low         Single         4           Yes
# 29   24     Low        Married         3            No
# 30   45    High         Single         2            No
# 31   40     Low         Single         4            No
# 32   52  Medium        Married         4           Yes
# 33   59  Medium         Single         4           Yes
# 34   18  Medium        Married         0           Yes
# 35   18  Medium        Married         3           Yes
# 36   40     Low         Single         2           Yes
# 37   29  Medium        Married         0           Yes
# 38   59     Low         Single         1            No
# 39   49  Medium        Married         4            No
# 40   49     Low         Single         1           Yes
# 41   43     Low        Married         3            No
# 42   47  Medium         Single         3            No
# 43   56    High        Married         2           Yes
# 44   44  Medium         Single         1           Yes
# 45   29    High        Married         2            No
# 46   28     Low         Single         2           Yes
# 47   35  Medium         Single         3            No
# 48   38  Medium         Single         1           Yes
# 49   19     Low        Married         1           Yes

# %%
data.shape
# Out:
# (200, 5)

# %%
data.info
# Out:
# <bound method DataFrame.info of      Age  Income Marital_Status  Children Car_Purchased
# 0     30  Medium        Married         4            No
# 1     54    High        Married         3           Yes
# 2     49     Low         Single         3            No
# 3     39     Low        Married         2           Yes
# 4     57  Medium         Single         2            No
# ..   ...     ...            ...       ...           ...
# 195   30  Medium        Married         3            No
# 196   30    High         Single         1           Yes
# 197   42    High         Single         3            No
# 198   58  Medium        Married         0            No
# 199   39    High         Single         0           Yes
#
# [200 rows x 5 columns]>

# %%
from sklearn.preprocessing import LabelEncoder
model=LabelEncoder()

#for Income column
encoded_income=model.fit_transform(data['Income'])   #encode string values into numerical values
data['Income']=encoded_income

# %%
#for Marital_Status	 column
encoded_Marital_Status=model.fit_transform(data['Marital_Status'])   #encode string values into numerical values
data['Marital_Status']=encoded_Marital_Status

# %%
# Divide data set into X amd y to train and test

x=data.drop('Car_Purchased',axis=1)  #drop the cloumn of get as y from data set then remainnig data set ids allocating to x to training
x.head(5)
# Out:
#    Age  Income  Marital_Status  Children
# 0   30       2               0         4
# 1   54       0               0         3
# 2   49       1               1         3
# 3   39       1               0         2
# 4   57       2               1         2

# %%
y=data['Car_Purchased']
y.head(5)        #get y value as the precaction value
# Out:
# 0     No
# 1    Yes
# 2     No
# 3    Yes
# 4     No
# Name: Car_Purchased, dtype: object

# %%
#divide data set into trainning and testing

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape #get 8 values from 10 values to tain
# Out:
# (160, 4)

# %%
from sklearn.tree import DecisionTreeClassifier
obj=DecisionTreeClassifier()
obj.fit(x_train,y_train)            #create decision tree model and train the trainnig data set using it
# Out:
# DecisionTreeClassifier()

# %%
pred=obj.predict(x_test)   #using model, give testing data and get predicated y values
pred
# Out:
# array(['No', 'No', 'Yes', 'No', 'No', 'No', 'Yes', 'No', 'No', 'Yes',
#        'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes',
#        'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'No', 'No',
#        'No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No'],
#       dtype=object)

# %%
#considering the performance of the predicted values
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.5

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,pred)
# Out:
# array([[13, 10],
#        [10,  7]], dtype=int64)
